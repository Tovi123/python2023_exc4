# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import re

# %%
def madlan_apartments():
    url = "https://www.madlan.co.il/for-sale/גבעת-שמואל-ישראל"
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.164 Safari/537.36 Edg/91.0.864.59'}
    response = requests.get(url,headers= headers)
    if response.status_code == 200:
        print("Success")
    else:
        print("Failure")
    soup = BeautifulSoup(response.content, 'html.parser')

    data = {}
    type_list = list()
    room_number_list = list()
    Area_list = list()
    Street_info = list()
    price_list = list()
    street_num = list()
    Street = list()
    number_in_street = list()
    city_area = list()

    for type_ in soup.find_all('div', {'data-auto': 'property-class', 'class': 'css-1i00gl6 e1sx3tzs17'}):
        type_list.append(type_.get_text())
    for room in soup.find_all('div', {'data-auto': 'property-rooms', 'class': 'css-1i00gl6 e1sx3tzs17'}):
        room_number_list.append(room.get_text())
    for area in soup.find_all('div', {'data-auto': 'property-size', 'class': 'css-1i00gl6 e1sx3tzs17'}):
        Area_list.append(area.get_text())
    for street in soup.find_all('div', {'data-auto': 'property-address', 'class': 'css-v4h09j e1sx3tzs16'}):
        Street_info.append(street.get_text())
    for i in Street_info:
        i = i.split(',')
        if len(i) == 2:
            area = i[1]
            address = i[0]
            street_num.append(address.strip())
        else:
            area = i[0]
        city_area.append(area.strip())
    for item in street_num:
        match = re.search(r'\b(\d+)\b', item)
        if match:
            number_in_street.append(match.group(1))
            Street.append(re.sub(r'\b\d+\b', '', item).strip())
        else:
            number_in_street.append(' ')
            Street.append(item)
    for price in soup.find_all('div', {'data-auto': 'property-price', 'class': 'css-19tpcfu eu6esji3'}):
        price_text = price.get_text()
        price_cut = price_text[:10]
        price_list.append(price_cut)

    type_list = type_list[:len(Street)]
    room_number_list = room_number_list[:len(Street)]
    Area_list = Area_list[:len(Street)]
    city_area = city_area[:len(Street)]
    price_list = price_list[:len(Street)]

    city_list = soup.find('div' ,{'class':'css-7so23d e3vrfmg6','data-auto':"breadcrumb-text"})
    data['City'] = city_list
    data['type'] = type_list
    data['room_number'] = room_number_list
    data['Area'] = Area_list
    data['Street'] = Street
    data['number_in_street'] = number_in_street
    data['city_area'] = city_area
    data['price'] = price_list

    return data

# %%
data= pd.DataFrame(madlan_apartments())
data
# Out:
# Success
#           City          type room_number     Area            Street  \
# 0   גבעת שמואל          דירה       6 חד׳  175 מ"ר              השקד
# 1   גבעת שמואל          דירה       4 חד׳  122 מ"ר         יצחק שמיר
# 2   גבעת שמואל          דירה       4 חד׳  100 מ"ר         רזיאל דוד
# 3   גבעת שמואל       דירת גן     6.5 חד׳  175 מ"ר            ביאליק
# 4   גבעת שמואל          דירה       4 חד׳  100 מ"ר              אילן
# 5   גבעת שמואל          דירה       4 חד׳  106 מ"ר  אורי צבי גרינברג
# 6   גבעת שמואל    קוטג' טורי     4.5 חד׳   99 מ"ר      לוחמי הגטאות
# 7   גבעת שמואל       פנטהאוז       6 חד׳  182 מ"ר             סירני
# 8   גבעת שמואל          דירה       6 חד׳  160 מ"ר         יצחק שמיר
# 9   גבעת שמואל       פנטהאוז       6 חד׳  225 מ"ר           בר אילן
# 10  גבעת שמואל          דירה       5 חד׳  113 מ"ר          מוטה גור
# 11  גבעת שמואל       דירת גן       5 חד׳  135 מ"ר         טרומפלדור
# 12  גבעת שמואל          דירה       5 חד׳  126 מ"ר         סמטת בוני
# 13  גבעת שמואל          דירה       5 חד׳  140 מ"ר         יצחק שמיר
# 14  גבעת שמואל          דירה     5.5 חד׳  140 מ"ר         בגין מנחם
# 15  גבעת שמואל          דירה       6 חד׳  143 מ"ר              השקד
# 16  גבעת שמואל          דירה       5 חד׳  156 מ"ר         בגין מנחם
# 17  גבעת שמואל          דירה       5 חד׳  125 מ"ר             הנשיא
# 18  גבעת שמואל         קוטג'       7 חד׳  240 מ"ר        פיקסלר צבי
# 19  גבעת שמואל       דירת גג       6 חד׳  200 מ"ר         יצחק שמיר
# 20  גבעת שמואל          דירה     3.5 חד׳   79 מ"ר            הרימון
# 21  גבעת שמואל          דירה       5 חד׳  142 מ"ר  אורי צבי גרינברג
# 22  גבעת שמואל       פנטהאוז       6 חד׳  200 מ"ר         גוש עציון
# 23  גבעת שמואל  מיני פנטהאוז       5 חד׳  150 מ"ר        ז'בוטינסקי
# 24  גבעת שמואל          דירה       4 חד׳  108 מ"ר              בארי
# 25  גבעת שמואל          דירה     4.5 חד׳  106 מ"ר         בן גוריון
# 26  גבעת שמואל        דופלקס       7 חד׳  160 מ"ר           ירושלים
#
#    number_in_street               city_area       price
# 0                 8                רמת אילן  ₪4,500,000
# 1                12           רמת הדר החדשה  ₪3,280,000
# 2                                   רמת הדר  ₪3,290,000
# 3                             השכונה הותיקה  ₪4,950,000
# 4                20                רמת אילן  ₪2,900,000
# 5                 2                 רמת הדר  ₪3,200,000
# 6                                     גיורא  ₪3,100,000
# 7                             השכונה הותיקה  ₪4,800,000
# 8                 9           רמת הדר החדשה  ₪4,150,000
# 9                             השכונה הותיקה  ₪4,500,000
# 10               12                 רמת הדר  ₪100,000בב
# 11                                    גיורא  ₪4,900,000
# 12                3                 רמת הדר  ₪3,300,000
# 13               13           רמת הדר החדשה  ₪3,850,000
# 14                1                 רמת הדר  ₪3,800,000
# 15                4                          ₪3,550,000
# 16               23                רמת אילן  ₪4,050,000
# 17               11                 רמת הדר  ₪3,500,000
# 18               23                    השחר  ₪7,600,000
# 19                            השכונה הותיקה  ₪5,500,000
# 20                8                   גיורא  ₪2,450,000
# 21                7                 רמת הדר  ₪3,500,000
# 22                                    גיורא  ₪4,990,000
# 23               50           רמת הדר החדשה  ₪5,800,000
# 24                7  רמת הדקלים-בית וקאנטרי  ₪3,050,000
# 25               11                 רמת הדר  ₪3,200,000
# 26               10                 רמת הדר  ₪5,390,000

# %%
data.to_csv('property_final.csv',encoding='utf-8-sig',index = False)
